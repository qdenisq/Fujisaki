# %% [markdown]
# # Fujisaki curve

# %% [markdown]
# ## create vector of parameters, based on radom disctribution

# %%
from fujisaki_utils import generate_fujisaki_params
import fujisaki_utils
p = generate_fujisaki_params(min_Fb=10.0, max_Fb=50.0, min_I=2, min_J=5, min_a=2.0, min_b=3.0)
# Out:
# Fujisaki parameters:
# Fb = 20.6604064806
# a = 2.93031487801
# b = 28.9792861176
# y = 0.273042516586
# I = 3
# Ap = [-0.18796463  0.35306983  0.33686462]
# T0p = [ 0.06519024  0.13085991  0.76533955]
# J = 8
# Aa = [ 0.29556665  0.24970736  0.06376237  0.24515148  0.10843581  0.0037536
#   0.30342409  0.46943601]
# T1a = [ 0.06275662  0.15487699  0.25870835  0.34840889  0.47923629  0.64136162
#   0.67232792  0.9551343 ]
# T2a = [ 0.06451581  0.19184786  0.32042609  0.40805631  0.55422026  0.65415593
#   0.86075395  0.95837526]

# %%
# %matplotlib inline
x, y = fujisaki_utils.generate_fujisaki_curve(**p)

# %%
fujisaki_utils.save_obj(p, 'params')
