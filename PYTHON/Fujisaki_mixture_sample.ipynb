# %% [markdown]
# # Fujisaki curve

# %% [markdown]
# ## create vector of parameters, based on radom disctribution

# %%
from fujisaki_utils import generate_fujisaki_params
import fujisaki_utils
p = generate_fujisaki_params(min_Fb=10.0, max_Fb=50.0, min_I=2, min_J=5, min_a=2.0, min_b=3.0)
# Out:
# Fujisaki parameters:
# Fb = 21.933558475
# a = 5.95623565575
# b = 4.57843793668
# y = 0.757213466508
# I = 6
# Ap = [-0.38476428  0.12614482 -0.32615666  0.26566819 -0.3244508  -0.31778325]
# T0p = [ 0.09356931  0.10111643  0.51150631  0.6801425   0.72689907  0.95460445]
# J = 8
# Aa = [ 0.40999647  0.10031273  0.49622254  0.0631122   0.49723109  0.49802539
#   0.44977366  0.04610078]
# T1a = [ 0.07345868  0.26074464  0.34730149  0.42858051  0.62977675  0.66155989
#   0.79132805  0.89056751]
# T2a = [ 0.17530726  0.30753052  0.38114588  0.53123362  0.63895218  0.79025914
#   0.79628204  0.97509343]

# %%
# %matplotlib inline
x, y = fujisaki_utils.generate_fujisaki_curve(**p)

# %%
fujisaki_utils.save_obj(p, 'params')
