# %% [markdown]
# # Fujisaki curve

# %% [markdown]
# ## create vector of parameters, based on radom disctribution

# %%
from fujisaki_utils import generate_fujisaki_params
import fujisaki_utils
p = generate_fujisaki_params(max_Fb=50.0)
# Out:
# Fujisaki parameters:
# Fb = 17.3093152822
# a = 0.228343252812
# b = 7.48368415454
# y = 0.645249963357
# I = 2
# Ap = [ 0.39550345 -0.27596198]
# T0p = [ 0.13777023  0.50545397]
# J = 7
# Aa = [ 0.11412453 -0.35272391 -0.38717831  0.44310863  0.16505276  0.03372835
#   0.18480914]
# T1a = [ 0.03348839  0.2325121   0.30184983  0.48962499  0.56660997  0.83965578
#   0.84614233]
# T2a = [ 0.20654341  0.23262257  0.3292884   0.55838372  0.6097725   0.84273223
#   0.86037261]

# %%
p['Ap']=p['Ap']*100
p['Aa']=p['Aa']*100

# %%
x, y = fujisaki_utils.generate_fujisaki_curve(show=True, verbose=False, time=5.0, fs=20000, **p)

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
generate_fujisaki_curve(True, 5.0, 20000, p)

# %%
x = np.linspace(0, 3*np.pi, 500)
y = np.sin(x**2)
plt.plot(x, y)
