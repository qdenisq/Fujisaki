# %% [markdown]
# # Fujisaki curve

# %% [markdown]
# ## create vector of parameters, based on radom disctribution

# %%
from fujisaki_utils import generate_fujisaki_params
import fujisaki_utils
p = generate_fujisaki_params(min_Fb=10.0, max_Fb=50.0, min_I=2, min_J=5, min_a=2.0, min_b=3.0)
# Out:
# Fujisaki parameters:
# Fb = 14.7696488763
# a = 7.49902850215
# b = 29.1502088552
# y = 0.0991690351224
# I = 4
# Ap = [ 0.11606367  0.0955992  -0.48185036 -0.27840865]
# T0p = [ 0.26740875  0.33142852  0.8374235   0.92042849]
# J = 7
# Aa = [ 0.05754124  0.0570811   0.39203639  0.35789063  0.16357806  0.21781532
#   0.30695604]
# T1a = [ 0.06489572  0.12280591  0.301632    0.46183459  0.52850404  0.68404464
#   0.85974278]
# T2a = [ 0.11415395  0.29750444  0.37374607  0.47879026  0.58625675  0.83192703
#   0.96465545]

# %%
# %matplotlib inline
x, y = fujisaki_utils.generate_fujisaki_curve(show=True, verbose=False, time=5.0, fs=20000, **p)

# %%
fujisaki_utils.save_obj(p, 'params')

# %%
loaded = fujisaki_utils.load_obj('params')
print loaded

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
generate_fujisaki_curve(True, 5.0, 20000, p)

# %%
x = np.linspace(0, 3*np.pi, 500)
y = np.sin(x**2)
plt.plot(x, y)
