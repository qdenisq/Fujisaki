# %% [markdown]
# # Statistical Analysis of report

# %% [markdown]
# ## Load report

# %%
import utils
import numpy as np
directory = r'C:\Users\s3628075\Study\Fujisaki\DataBase\enterface\NewFolder/'
report = utils.load_obj(directory+'Fujisaki_Params.pkl')
fnames, params = zip(*report.items())
fnames = np.array(fnames)
Fb = a = b = I = J = Aa_all = Ap_all = np.empty(1)
for p in params:
    Fb= np.append(Fb, p['Fb'])
    a = np.append(a, p['a'])
    b = np.append(b, p['b'])
    I = np.append(I, p['I'])
    J = np.append(J, p['J'])
    Aa_all = np.append(Aa_all, p['Aa'])
    Ap_all = np.append(Ap_all, p['Ap'])
print("Loading report completed")
# Out:
# Loading report completed

# %% [markdown]
# ## Look at how parameters are distributed across the whole corpus

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
# plot Fb
hFb = utils.plot_hist(Fb, "Fb", 2.0)
# plot a
ha = utils.plot_hist(a, "Alpha", 0.1)
# plot I
hI = utils.plot_hist(I, "I", 1.0)
# plot J
hJ = utils.plot_hist(J, "J", 1.0)
# plot Aa
hAa = utils.plot_hist(Aa_all, "Aa", 0.1, verbose=True)
# plot Ap
hAp = utils.plot_hist(Ap_all, "Ap", 0.1, verbose=True)
plt.show()
# Out:
# Aa length: 3084; min_value: -0.45; max_value: 1.3957
# Ap length: 693; min_value: 0.0; max_value: 9.7687

# %% [markdown]
# ## Calculate error

# %%
# load emotions.pkl and subjects.pkl utils.load_obj()
emotions = utils.load_obj(directory+'emotions.pkl')
subjects = utils.load_obj(directory+'subjects.pkl')

# %% [markdown]
# ## Error distribution across emotions

# %%
bins = np.linspace(0, 0.1, 100) 
for key in emotions.keys():
    plt.figure(figsize=(18,5))
    plt.hist(emotions[key], bins, alpha = 0.3, label=str(key), normed=True)
    plt.xlabel('Err')
    plt.ylabel('Frequency')
    plt.legend(loc = 'upper right')
    plt.show()

# %% [markdown]
# ## Error distribution across subjects

# %%
bins = np.linspace(0, 0.1, 100) 
for key in subjects.keys():
    print key
    if key % 1 == 0:
        plt.figure(figsize=(18,5))
        plt.hist(subjects[key], bins, alpha = 0.3, label=str(key), normed=True)
        plt.xlabel('Err')
        plt.ylabel('Frequency')
        plt.legend(loc = 'upper right')
        plt.show()
# Out:
# 0

# %% [markdown]
# ## t-Test (difference of error through neutral and emotional speech)

# %%
import scipy.stats as st
import prettytable
t_test = np.empty(0, dtype=[('E1', 'a10'), ('E2', 'a10'), ('T', 'f'), ('P', 'f')])
for e in emotions.keys():
    for e2 in emotions.keys():
        test = st.ttest_ind(emotions[e], emotions[e2], equal_var = False)
        t_test = np.append(t_test, np.array([(e, e2, test[0], test[1])], dtype=t_test.dtype))
        anova = st.f_oneway(emotions[e], emotions[e2])
        print anova
        print test
pretty_tbl = prettytable.PrettyTable(t_test.dtype.names)
for r in t_test:
    pretty_tbl.add_row(r)
print(pretty_tbl)
# Out:
# F_onewayResult(statistic=-1.2541445286541079e-31, pvalue=nan)
# Ttest_indResult(statistic=0.0, pvalue=1.0)
# F_onewayResult(statistic=0.83876098761093953, pvalue=0.36095663067015538)
# Ttest_indResult(statistic=-1.3433089650670238, pvalue=0.18146761013825272)
# F_onewayResult(statistic=0.082256851271581818, pvalue=0.77480644475922678)
# Ttest_indResult(statistic=-0.27673271806048261, pvalue=0.78288657266087014)
# F_onewayResult(statistic=0.035847571253868261, pvalue=0.85011710117639905)
# Ttest_indResult(statistic=-0.21908678364314632, pvalue=0.82714630744739592)
# F_onewayResult(statistic=0.86156055014785904, pvalue=0.35567967339464657)
# Ttest_indResult(statistic=0.90921441486466537, pvalue=0.36620146625087846)
# F_onewayResult(statistic=19.738305989220837, pvalue=2.1108669043271402e-05)
# Ttest_indResult(statistic=4.5101062710004962, pvalue=1.9993007693443254e-05)
# F_onewayResult(statistic=nan, pvalue=nan)
# Ttest_indResult(statistic=nan, pvalue=nan)
# F_onewayResult(statistic=0.83876098761093965, pvalue=0.36095663067015538)
# Ttest_indResult(statistic=1.3433089650670238, pvalue=0.18146761013825272)
# F_onewayResult(statistic=4.9298942440755605e-32, pvalue=1.0)
# Ttest_indResult(statistic=0.0, pvalue=1.0)
# F_onewayResult(statistic=0.59240645219127275, pvalue=0.44251026453906117)
# Ttest_indResult(statistic=1.0933580886455718, pvalue=0.27578270848944697)
# F_onewayResult(statistic=0.40403599855415573, pvalue=0.52572813324967216)
# Ttest_indResult(statistic=0.62514847656014938, pvalue=0.53279661198411921)
# F_onewayResult(statistic=0.76954376531215996, pvalue=0.38164933177602767)
# Ttest_indResult(statistic=1.5725209283854362, pvalue=0.11812747333851208)
# F_onewayResult(statistic=2.0769432913819603, pvalue=0.15127673118103202)
# Ttest_indResult(statistic=2.1864531275978196, pvalue=0.030601293390248863)
# F_onewayResult(statistic=nan, pvalue=nan)
# Ttest_indResult(statistic=nan, pvalue=nan)
# F_onewayResult(statistic=0.082256851271581874, pvalue=0.77480644475922678)
# Ttest_indResult(statistic=0.27673271806048261, pvalue=0.78288657266087014)
# F_onewayResult(statistic=0.59240645219127264, pvalue=0.44251026453906117)
# Ttest_indResult(statistic=-1.0933580886455718, pvalue=0.27578270848944697)
# F_onewayResult(statistic=2.9276070025018833e-32, pvalue=1.0)
# Ttest_indResult(statistic=0.0, pvalue=1.0)
# F_onewayResult(statistic=0.0086188102699831272, pvalue=0.92617664738593497)
# Ttest_indResult(statistic=-0.10922985406400051, pvalue=0.91324877960055451)
# F_onewayResult(statistic=0.41477035062380202, pvalue=0.52121442664885553)
# Ttest_indResult(statistic=0.72954260334371135, pvalue=0.46806349296126204)
# F_onewayResult(statistic=3.9774509518886072, pvalue=0.048680820311500936)
# Ttest_indResult(statistic=1.9597970242236986, pvalue=0.05505998727294828)
# F_onewayResult(statistic=nan, pvalue=nan)
# Ttest_indResult(statistic=nan, pvalue=nan)
# F_onewayResult(statistic=0.035847571253868261, pvalue=0.85011710117639905)
# Ttest_indResult(statistic=0.21908678364314632, pvalue=0.82714630744739592)
# F_onewayResult(statistic=0.40403599855415562, pvalue=0.52572813324967216)
# Ttest_indResult(statistic=-0.62514847656014938, pvalue=0.53279661198411921)
# F_onewayResult(statistic=0.0086188102699831272, pvalue=0.92617664738593497)
# Ttest_indResult(statistic=0.10922985406400051, pvalue=0.91324877960055451)
# F_onewayResult(statistic=-5.3659761767462549e-33, pvalue=nan)
# Ttest_indResult(statistic=0.0, pvalue=1.0)
# F_onewayResult(statistic=0.078364728810822154, pvalue=0.7800331436868807)
# Ttest_indResult(statistic=0.39801526685556599, pvalue=0.69166636145566285)
# F_onewayResult(statistic=0.4842150237765892, pvalue=0.4877519415897632)
# Ttest_indResult(statistic=0.82873599326363878, pvalue=0.40979422793246389)
# F_onewayResult(statistic=nan, pvalue=nan)
# Ttest_indResult(statistic=nan, pvalue=nan)
# F_onewayResult(statistic=0.86156055014785893, pvalue=0.35567967339464657)
# Ttest_indResult(statistic=-0.90921441486466537, pvalue=0.36620146625087846)
# F_onewayResult(statistic=0.76954376531216018, pvalue=0.38164933177602767)
# Ttest_indResult(statistic=-1.5725209283854362, pvalue=0.11812747333851208)
# F_onewayResult(statistic=0.41477035062380208, pvalue=0.52121442664885553)
# Ttest_indResult(statistic=-0.72954260334371135, pvalue=0.46806349296126204)
# F_onewayResult(statistic=0.078364728810822154, pvalue=0.7800331436868807)
# Ttest_indResult(statistic=-0.39801526685556599, pvalue=0.69166636145566285)
# F_onewayResult(statistic=2.2009356255322773e-31, pvalue=1.0)
# Ttest_indResult(statistic=0.0, pvalue=1.0)
# F_onewayResult(statistic=7.5780035370141654, pvalue=0.0071322829436245251)
# Ttest_indResult(statistic=2.4508255186495527, pvalue=0.017877582958982865)
# F_onewayResult(statistic=nan, pvalue=nan)
# Ttest_indResult(statistic=nan, pvalue=nan)
# F_onewayResult(statistic=19.738305989220837, pvalue=2.1108669043271402e-05)
# Ttest_indResult(statistic=-4.5101062710004962, pvalue=1.9993007693443254e-05)
# F_onewayResult(statistic=2.0769432913819603, pvalue=0.15127673118103202)
# Ttest_indResult(statistic=-2.1864531275978196, pvalue=0.030601293390248863)
# F_onewayResult(statistic=3.9774509518886072, pvalue=0.048680820311500936)
# Ttest_indResult(statistic=-1.9597970242236986, pvalue=0.05505998727294828)
# F_onewayResult(statistic=0.48421502377658948, pvalue=0.4877519415897632)
# Ttest_indResult(statistic=-0.82873599326363878, pvalue=0.40979422793246389)
# F_onewayResult(statistic=7.5780035370141663, pvalue=0.0071322829436245251)
# Ttest_indResult(statistic=-2.4508255186495527, pvalue=0.017877582958982865)
# F_onewayResult(statistic=-3.9735708481251467e-32, pvalue=nan)
# Ttest_indResult(statistic=0.0, pvalue=1.0)
# F_onewayResult(statistic=nan, pvalue=nan)
# Ttest_indResult(statistic=nan, pvalue=nan)
# F_onewayResult(statistic=nan, pvalue=nan)
# Ttest_indResult(statistic=nan, pvalue=nan)
# F_onewayResult(statistic=nan, pvalue=nan)
# Ttest_indResult(statistic=nan, pvalue=nan)
# F_onewayResult(statistic=nan, pvalue=nan)
# Ttest_indResult(statistic=nan, pvalue=nan)
# F_onewayResult(statistic=nan, pvalue=nan)
# Ttest_indResult(statistic=nan, pvalue=nan)
# F_onewayResult(statistic=nan, pvalue=nan)
# Ttest_indResult(statistic=nan, pvalue=nan)
# F_onewayResult(statistic=nan, pvalue=nan)
# Ttest_indResult(statistic=nan, pvalue=nan)
# F_onewayResult(statistic=nan, pvalue=nan)
# Ttest_indResult(statistic=nan, pvalue=nan)
# +---------+---------+-----------+------------+
# |    E1   |    E2   |     T     |     P      |
# +---------+---------+-----------+------------+
# |   joy   |   joy   |    0.0    |    1.0     |
# |   joy   |  angry  |  -1.34331 |  0.181468  |
# |   joy   |   sad   | -0.276733 |  0.782887  |
# |   joy   | neutral | -0.219087 |  0.827146  |
# |   joy   | disgust |  0.909214 |  0.366201  |
# |   joy   |   fear  |  4.51011  | 1.9993e-05 |
# |   joy   |  bored  |    nan    |    nan     |
# |  angry  |   joy   |  1.34331  |  0.181468  |
# |  angry  |  angry  |    0.0    |    1.0     |
# |  angry  |   sad   |  1.09336  |  0.275783  |
# |  angry  | neutral |  0.625148 |  0.532797  |
# |  angry  | disgust |  1.57252  |  0.118127  |
# |  angry  |   fear  |  2.18645  | 0.0306013  |
# |  angry  |  bored  |    nan    |    nan     |
# |   sad   |   joy   |  0.276733 |  0.782887  |
# |   sad   |  angry  |  -1.09336 |  0.275783  |
# |   sad   |   sad   |    0.0    |    1.0     |
# |   sad   | neutral |  -0.10923 |  0.913249  |
# |   sad   | disgust |  0.729543 |  0.468064  |
# |   sad   |   fear  |   1.9598  |  0.05506   |
# |   sad   |  bored  |    nan    |    nan     |
# | neutral |   joy   |  0.219087 |  0.827146  |
# | neutral |  angry  | -0.625148 |  0.532797  |
# | neutral |   sad   |  0.10923  |  0.913249  |
# | neutral | neutral |    0.0    |    1.0     |
# | neutral | disgust |  0.398015 |  0.691666  |
# | neutral |   fear  |  0.828736 |  0.409794  |
# | neutral |  bored  |    nan    |    nan     |
# | disgust |   joy   | -0.909214 |  0.366201  |
# | disgust |  angry  |  -1.57252 |  0.118127  |
# | disgust |   sad   | -0.729543 |  0.468064  |
# | disgust | neutral | -0.398015 |  0.691666  |
# | disgust | disgust |    0.0    |    1.0     |
# | disgust |   fear  |  2.45083  | 0.0178776  |
# | disgust |  bored  |    nan    |    nan     |
# |   fear  |   joy   |  -4.51011 | 1.9993e-05 |
# |   fear  |  angry  |  -2.18645 | 0.0306013  |
# |   fear  |   sad   |  -1.9598  |  0.05506   |
# |   fear  | neutral | -0.828736 |  0.409794  |
# |   fear  | disgust |  -2.45083 | 0.0178776  |
# |   fear  |   fear  |    0.0    |    1.0     |
# |   fear  |  bored  |    nan    |    nan     |
# |  bored  |   joy   |    nan    |    nan     |
# |  bored  |  angry  |    nan    |    nan     |
# |  bored  |   sad   |    nan    |    nan     |
# |  bored  | neutral |    nan    |    nan     |
# |  bored  | disgust |    nan    |    nan     |
# |  bored  |   fear  |    nan    |    nan     |
# |  bored  |  bored  |    nan    |    nan     |
# +---------+---------+-----------+------------+
